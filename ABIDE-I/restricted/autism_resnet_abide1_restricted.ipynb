# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nibabel as nib
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input, Concatenate
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, confusion_matrix

# %%
# Parameters
IMG_SIZE = (128, 128)
BATCH_SIZE = 32
DATA_DIR = "./abide1_preprocessed_age_15_or_less"
CSV_FILE = "./abide_1_15_or_less.csv"

# %%
# Load CSV
df = pd.read_csv(CSV_FILE, dtype={'SUB_ID': str})

def load_nii_file(file_path):
    try:
        img = nib.load(file_path).get_fdata()
        if len(img.shape) != 2:
            print(f"Warning: {file_path} has unexpected shape {img.shape}")
            return None
        img = tf.image.resize(img[..., np.newaxis], IMG_SIZE).numpy()
        img = (img - img.min()) / (img.max() - img.min() + 1e-10)
        return img
    except Exception as e:
        print(f"Error loading {file_path}: {str(e)}")
        return None

# %%
# Load images and labels
images, labels = [], []
for idx, row in df.iterrows():
    sub_id = row["SUB_ID"]
    label = row["DX_GROUP"] - 1
    nii_path = os.path.join(DATA_DIR, sub_id, f"{sub_id}_.nii")
    if os.path.exists(nii_path):
        img = load_nii_file(nii_path)
        if img is not None:
            images.append(img)
            labels.append(label)
    else:
        print(f"File not found: {nii_path}")

images = np.array(images)
labels = np.array(labels)
print(f"Total images loaded: {len(images)}, Total labels: {len(labels)}")
if len(images) == 0 or len(labels) == 0:
    raise ValueError("No images or labels loaded.")
# Out:
# File not found: ./abide1_preprocessed_age_15_or_less\51310\51310_.nii
# Total images loaded: 588, Total labels: 588

# %%
# Train-validation split
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)
print(f"Training set: {len(X_train)}, Validation set: {len(X_val)}")

# Define ResNet50 Model
base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(128, 128, 3))
base_model.trainable = False

inputs = Input(shape=(128, 128, 1))
x = Concatenate()([inputs, inputs, inputs])  # Grayscale to RGB
x = base_model(x, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.25)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs, outputs)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Training set: 470, Validation set: 118
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ input_layer_1[0]… │
# │ (Concatenate)       │ 3)                │            │ input_layer_1[0]… │
# │                     │                   │            │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 4, 4,      │ 23,587,712 │ concatenate[0][0] │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    262,272 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,850,113 (90.98 MB)
#  Trainable params: 262,401 (1.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# Training
history = model.fit(X_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=20,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.5497 - loss: 0.7746 - val_accuracy: 0.5678 - val_loss: 0.6830
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 975ms/step - accuracy: 0.4915 - loss: 0.7427 - val_accuracy: 0.5678 - val_loss: 0.6828
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.5200 - loss: 0.7136 - val_accuracy: 0.5678 - val_loss: 0.6861
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.5409 - loss: 0.7194 - val_accuracy: 0.5678 - val_loss: 0.6821
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5436 - loss: 0.6963 - val_accuracy: 0.5678 - val_loss: 0.6835
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 939ms/step - accuracy: 0.5097 - loss: 0.7059 - val_accuracy: 0.5593 - val_loss: 0.6849
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.4627 - loss: 0.7158 - val_accuracy: 0.5169 - val_loss: 0.6898
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 20s 973ms/step - accuracy: 0.5127 - loss: 0.7189 - val_accuracy: 0.5678 - val_loss: 0.6822
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 973ms/step - accuracy: 0.5392 - loss: 0.6972 - val_accuracy: 0.5169 - val_loss: 0.6863
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 909ms/step - accuracy: 0.4956 - loss: 0.7153 - val_accuracy: 0.5678 - val_loss: 0.6825
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.5467 - loss: 0.7044 - val_accuracy: 0.5424 - val_loss: 0.6912
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 891ms/step - accuracy: 0.5148 - loss: 0.7080 - val_accuracy: 0.5339 - val_loss: 0.6886
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 923ms/step - accuracy: 0.5491 - loss: 0.6947 - val_accuracy: 0.5339 - val_loss: 0.6925
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.5175 - loss: 0.7015 - val_accuracy: 0.5424 - val_loss: 0.6874
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.5466 - loss: 0.6903 - val_accuracy: 0.4746 - val_loss: 0.6992
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.5275 - loss: 0.6992 - val_accuracy: 0.5508 - val_loss: 0.6844
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.5131 - loss: 0.6936 - val_accuracy: 0.5169 - val_loss: 0.6956
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.5331 - loss: 0.6909 - val_accuracy: 0.5254 - val_loss: 0.6866
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5445 - loss: 0.6875 - val_accuracy: 0.5254 - val_loss: 0.6872
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5167 - loss: 0.6930 - val_accuracy: 0.5678 - val_loss: 0.6834

# %%
# Inference
NII_FILE = "./abide1_preprocessed_age_15_or_less/51177/51177_.nii"
def load_single_image(file_path):
    img = load_nii_file(file_path)
    return np.expand_dims(img, axis=0)

img = load_single_image(NII_FILE)
prediction = model.predict(img)[0][0]
if prediction >= 0.5:
    print(f"Prediction: ASD (Confidence: {prediction:.4f})")
else:
    print(f"Prediction: TD (Confidence: {1 - prediction:.4f})")

# Evaluation
y_pred_val = model.predict(X_val).flatten()
y_pred_binary = (y_pred_val > 0.5).astype(int)

def evaluate_model(y_true, y_pred, y_prob=None, model_name=""):
    if model_name:
        print(f"--- Performance Metrics for {model_name} ---")

    metrics = {}
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    sensitivity = recall_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)

    metrics['Accuracy'] = accuracy
    metrics['F1-Score'] = f1
    metrics['Sensitivity'] = sensitivity
    metrics['Specificity'] = specificity

    print(f"Accuracy: {accuracy:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"Sensitivity (TPR): {sensitivity:.4f}")
    print(f"Specificity (TNR): {specificity:.4f}")

    if y_prob is not None:
        try:
            auc = roc_auc_score(y_true, y_prob)
            metrics['AUC-ROC'] = auc
            print(f"AUC-ROC: {auc:.4f}")
        except ValueError:
            print("Warning: AUC-ROC requires both classes present.")
    return metrics

# Call evaluation
evaluation_metrics = evaluate_model(y_val, y_pred_binary, y_pred_val, model_name="ResNet50 ABIDE")
print("\nValidation Metrics:", evaluation_metrics)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# Prediction: ASD (Confidence: 0.5353)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step
# --- Performance Metrics for ResNet50 ABIDE ---
# Accuracy: 0.5678
# F1-Score: 0.7243
# Sensitivity (TPR): 1.0000
# Specificity (TNR): 0.0000
# AUC-ROC: 0.5572
#
# Validation Metrics: {'Accuracy': 0.5677966101694916, 'F1-Score': 0.7243243243243244, 'Sensitivity': 1.0, 'Specificity': np.float64(0.0), 'AUC-ROC': np.float64(0.5572139303482586)}
